# %% [markdown]
# # Possum head length prediction with Decision Tree Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load dataset

# %%
df = pd.read_csv('possum.csv')
df.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
X = np.reshape(df.iloc[:, 6].values, (len(df.iloc[:, 6].values), 1))
y = np.reshape(df.iloc[:, 5].values, (len(df.iloc[:, 5].values), 1))
print(X)
print(y)
# Out:
# [[60.4]
#  [57.6]
#  [60. ]
#  [57.1]
#  [56.3]
#  [54.8]
#  [58.2]
#  [57.6]
#  [56.3]
#  [58. ]
#  [57.2]
#  [55.6]
#  [59.9]
#  [57.6]
#  [57.6]
#  [56. ]
#  [67.7]
#  [55.7]
#  [55.4]
#  [56.3]
#  [58.1]
#  [58.5]
#  [56.1]
#  [54.9]
#  [58.5]
#  [59. ]
#  [54.5]
#  [56.8]
#  [56. ]
#  [54.4]
#  [54.1]
#  [56.7]
#  [54.6]
#  [55.7]
#  [57.9]
#  [59.3]
#  [54.8]
#  [56. ]
#  [51.5]
#  [55. ]
#  [57. ]
#  [54.1]
#  [55.5]
#  [51.5]
#  [55.9]
#  [54.4]
#  [54.8]
#  [63.2]
#  [59.2]
#  [56.4]
#  [59.6]
#  [61. ]
#  [58.1]
#  [63. ]
#  [63.2]
#  [61.5]
#  [59.4]
#  [64.2]
#  [62.8]
#  [57.7]
#  [59. ]
#  [58. ]
#  [56.4]
#  [56.5]
#  [57.4]
#  [55.8]
#  [57.6]
#  [56. ]
#  [55.6]
#  [56.4]
#  [57.6]
#  [52.4]
#  [52.3]
#  [52. ]
#  [58.1]
#  [56.8]
#  [56.2]
#  [51. ]
#  [50. ]
#  [52.6]
#  [56. ]
#  [54. ]
#  [53.8]
#  [54.6]
#  [56.2]
#  [53.2]
#  [60.7]
#  [58. ]
#  [58.4]
#  [54.6]
#  [59.6]
#  [56.3]
#  [54. ]
#  [57.6]
#  [56.6]
#  [55.7]
#  [53.1]
#  [68.6]
#  [56.2]
#  [56. ]
#  [54.7]
#  [55. ]
#  [55.2]
#  [59.9]]
# [[ 94.1]
#  [ 92.5]
#  [ 94. ]
#  [ 93.2]
#  [ 91.5]
#  [ 93.1]
#  [ 95.3]
#  [ 94.8]
#  [ 93.4]
#  [ 91.8]
#  [ 93.3]
#  [ 94.9]
#  [ 95.1]
#  [ 95.4]
#  [ 92.9]
#  [ 91.6]
#  [ 94.7]
#  [ 93.5]
#  [ 94.4]
#  [ 94.8]
#  [ 95.9]
#  [ 96.3]
#  [ 92.5]
#  [ 94.4]
#  [ 95.8]
#  [ 96. ]
#  [ 90.5]
#  [ 93.8]
#  [ 92.8]
#  [ 92.1]
#  [ 92.8]
#  [ 94.3]
#  [ 91.4]
#  [ 90.6]
#  [ 94.4]
#  [ 93.3]
#  [ 89.3]
#  [ 92.4]
#  [ 84.7]
#  [ 91. ]
#  [ 88.4]
#  [ 85.3]
#  [ 90. ]
#  [ 85.1]
#  [ 90.7]
#  [ 91.4]
#  [ 90.1]
#  [ 98.6]
#  [ 95.4]
#  [ 91.6]
#  [ 95.6]
#  [ 97.6]
#  [ 93.1]
#  [ 96.9]
#  [103.1]
#  [ 99.9]
#  [ 95.1]
#  [ 94.5]
#  [102.5]
#  [ 91.3]
#  [ 95.7]
#  [ 91.3]
#  [ 92. ]
#  [ 96.9]
#  [ 93.5]
#  [ 90.4]
#  [ 93.3]
#  [ 94.1]
#  [ 98. ]
#  [ 91.9]
#  [ 92.8]
#  [ 85.9]
#  [ 82.5]
#  [ 88.7]
#  [ 93.8]
#  [ 92.4]
#  [ 93.6]
#  [ 86.5]
#  [ 85.8]
#  [ 86.7]
#  [ 90.6]
#  [ 86. ]
#  [ 90. ]
#  [ 88.4]
#  [ 89.5]
#  [ 88.2]
#  [ 98.5]
#  [ 89.6]
#  [ 97.7]
#  [ 92.6]
#  [ 97.8]
#  [ 90.7]
#  [ 89.2]
#  [ 91.8]
#  [ 91.6]
#  [ 94.8]
#  [ 91. ]
#  [ 93.2]
#  [ 93.3]
#  [ 89.5]
#  [ 88.6]
#  [ 92.4]
#  [ 91.5]
#  [ 93.6]]

# %% [markdown]
# ## Splitting the dataset into training set and testset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# ## Training the Decision Tree Model from the training data set

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ## Predicting the test set

# %%
y_pred = regressor.predict(X_test)

# %%
print(y_pred)
# Out:
# [92.1        90.7        94.35       91.75       86.7        93.3
#  93.2        92.3        93.3        92.1        92.5        86.7
#  98.5        92.5        92.5        85.3        92.3        96.3
#  94.15       92.33333333 84.7        94.9        88.4        94.5
#  87.6        93.8       ]

# %% [markdown]
# ## Calculate r2-Score

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.18319105686005

# %% [markdown]
# ## Conclusion: bad model! not suitable.
